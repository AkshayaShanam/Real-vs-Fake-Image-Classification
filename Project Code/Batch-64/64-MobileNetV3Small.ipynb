# %% [markdown]
# ## Fine-tuning CNN for AI-generated Image Detection
# In this notebook, we will explore the task of classifying images as real or AI-generated using fine-tuning techniques with several well-known CNN architectures. For this classification task, we will use the CIFAKE dataset, which includes both real and AI-generated images.
#
# Link for the dataset: [CIFAKE: Real and AI-Generated Synthetic Images](https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from IPython.display import Image
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
# Out:
# 2026-01-13 09:23:24.789098: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-13 09:23:24.789219: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-13 09:23:25.125496: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_dir = "/kaggle/input/cifake-real-and-ai-generated-synthetic-images/" # For Kaggle notebooks. If you run locally, point this line to the CIFAKE directory
print("Loading dataset from: " + dataset_dir)
# Out:
# Loading dataset from: /kaggle/input/cifake-real-and-ai-generated-synthetic-images/

# %%
# Check if GPUs are available for training 
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  2

# %%
img_height = 32
img_width = 32
batch_size = 64

# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/train",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

# Load the validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/test",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size,
  shuffle=False)

print("Training Classes:")
class_names = train_ds.class_names
print(class_names)

print("Testing Classes:")
class_names = val_ds.class_names
print(class_names)
# Out:
# Found 100000 files belonging to 2 classes.
# Found 20000 files belonging to 2 classes.
# Training Classes:
# ['FAKE', 'REAL']
# Testing Classes:
# ['FAKE', 'REAL']

# %%
def plot_metrics(history, metric, title):
    # Train metric
    plt.plot(history.history[metric], label=f"Training {metric.capitalize()}")
    # Validation metric
    plt.plot(history.history['val_' + metric], label=f"Validation {metric.capitalize()}")
    plt.xlabel("Epochs")
    plt.ylabel(metric.capitalize())
    plt.title(title)
    plt.legend()
    plt.show()
    
# Constant values that will be shared by all the models
val_true_classes = np.concatenate([y for x, y in val_ds], axis = 0)  # Get true labels
class_names = ['FAKE', 'REAL']
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %%
# Building the Transfer Learning model using MobileNetV3
MobileNet_base_model = tf.keras.applications.MobileNetV3Small(
    include_top = False, 
    weights = 'imagenet', 
    input_shape = (img_height, img_width, 3),
    pooling = 'max'
)
MobileNet_base_model.trainable = True

# Create a new model on top of the MobileNet base
inputs = tf.keras.Input(shape = (img_height, img_width, 3))
x = preprocess_input(inputs)
x = MobileNet_base_model(inputs, training = False)
x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001)(x)
x = Dense(256, 
          kernel_regularizer = regularizers.l2(0.01), 
          activity_regularizer = regularizers.l1(0.01), 
          bias_regularizer = regularizers.l1(0.01),
          activation = 'relu')(x)
x = Dropout(rate = .4, seed = 512)(x)       
x = Dense(64, activation = 'relu')(x)
outputs = Dense(1, activation = 'sigmoid')(x)
MobileNet_model = tf.keras.Model(inputs, outputs)

# Compile the Transfer Learning model
MobileNet_model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# Build the Transfer Learning model so we can see a summary
MobileNet_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  MobilenetV3small (Function  (None, 576)               939120
#  al)
#
#  batch_normalization (Batch  (None, 576)               2304
#  Normalization)
#
#  dense (Dense)               (None, 256)               147712
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1105649 (4.22 MB)
# Trainable params: 1092385 (4.17 MB)
# Non-trainable params: 13264 (51.81 KB)
# _________________________________________________________________

# %%
# Visualize the MobileNet model architecture
tf.keras.utils.plot_model(MobileNet_model, show_shapes = True, to_file = 'MobileNet_model.png')
Image('MobileNet_model.png')

# %%
# Finally, train the Transfer Learning model
print("Starting training with Transfer Learning using MobileNet...")
MobileNet_model_history = MobileNet_model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 100,
    verbose = 1,
    callbacks = [early_stopping]
)
print("Transfer Learning training finished.")
# Out:
# Starting training with Transfer Learning using MobileNet...
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768296439.049848     111 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1563/1563 [==============================] - 180s 95ms/step - loss: 0.3511 - accuracy: 0.9028 - precision: 0.8996 - recall: 0.9068 - val_loss: 0.2709 - val_accuracy: 0.9006 - val_precision: 0.9829 - val_recall: 0.8154
# Epoch 2/100
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.1805 - accuracy: 0.9359 - precision: 0.9377 - recall: 0.9339 - val_loss: 0.2879 - val_accuracy: 0.8893 - val_precision: 0.9903 - val_recall: 0.7863
# Epoch 3/100
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.1612 - accuracy: 0.9431 - precision: 0.9433 - recall: 0.9428 - val_loss: 0.1697 - val_accuracy: 0.9371 - val_precision: 0.9718 - val_recall: 0.9003
# Epoch 4/100
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.1482 - accuracy: 0.9489 - precision: 0.9510 - recall: 0.9466 - val_loss: 0.1807 - val_accuracy: 0.9398 - val_precision: 0.9085 - val_recall: 0.9781
# Epoch 5/100
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.2737 - accuracy: 0.8932 - precision: 0.8916 - recall: 0.8952 - val_loss: 0.3890 - val_accuracy: 0.8440 - val_precision: 0.9666 - val_recall: 0.7127
# Epoch 6/100
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.2454 - accuracy: 0.9062 - precision: 0.9051 - recall: 0.9076 - val_loss: 0.2155 - val_accuracy: 0.9176 - val_precision: 0.9303 - val_recall: 0.9029
# Epoch 7/100
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.2113 - accuracy: 0.9208 - precision: 0.9232 - recall: 0.9181 - val_loss: 0.1925 - val_accuracy: 0.9289 - val_precision: 0.9348 - val_recall: 0.9221
# Epoch 8/100
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.1911 - accuracy: 0.9293 - precision: 0.9298 - recall: 0.9287 - val_loss: 0.1896 - val_accuracy: 0.9262 - val_precision: 0.9624 - val_recall: 0.8870
# Epoch 9/100
# 1563/1563 [==============================] - 64s 41ms/step - loss: 0.1812 - accuracy: 0.9336 - precision: 0.9341 - recall: 0.9330 - val_loss: 0.2705 - val_accuracy: 0.9007 - val_precision: 0.8435 - val_recall: 0.9839
# Epoch 10/100
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.1739 - accuracy: 0.9367 - precision: 0.9383 - recall: 0.9348 - val_loss: 0.1758 - val_accuracy: 0.9336 - val_precision: 0.9120 - val_recall: 0.9598
# Epoch 11/100
# 1563/1563 [==============================] - 65s 41ms/step - loss: 0.1672 - accuracy: 0.9393 - precision: 0.9396 - recall: 0.9389 - val_loss: 0.2251 - val_accuracy: 0.9212 - val_precision: 0.8759 - val_recall: 0.9813
# Epoch 12/100
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.1635 - accuracy: 0.9416 - precision: 0.9429 - recall: 0.9402 - val_loss: 0.1631 - val_accuracy: 0.9431 - val_precision: 0.9369 - val_recall: 0.9501
# Epoch 13/100
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.1555 - accuracy: 0.9441 - precision: 0.9462 - recall: 0.9419 - val_loss: 0.1778 - val_accuracy: 0.9377 - val_precision: 0.9104 - val_recall: 0.9711
# Epoch 14/100
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.1503 - accuracy: 0.9464 - precision: 0.9485 - recall: 0.9441 - val_loss: 0.3211 - val_accuracy: 0.8824 - val_precision: 0.8136 - val_recall: 0.9922
# Epoch 15/100
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.1415 - accuracy: 0.9499 - precision: 0.9521 - recall: 0.9474 - val_loss: 0.2429 - val_accuracy: 0.9129 - val_precision: 0.8597 - val_recall: 0.9867
# Epoch 16/100
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.1389 - accuracy: 0.9519 - precision: 0.9531 - recall: 0.9506 - val_loss: 0.1743 - val_accuracy: 0.9424 - val_precision: 0.9229 - val_recall: 0.9656
# Epoch 17/100
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.1351 - accuracy: 0.9533 - precision: 0.9542 - recall: 0.9523 - val_loss: 0.1648 - val_accuracy: 0.9398 - val_precision: 0.9126 - val_recall: 0.9727
# Epoch 18/100
# 1563/1563 [==============================] - 65s 41ms/step - loss: 0.1305 - accuracy: 0.9544 - precision: 0.9562 - recall: 0.9524 - val_loss: 0.2010 - val_accuracy: 0.9326 - val_precision: 0.8968 - val_recall: 0.9777
# Epoch 19/100
# 1563/1563 [==============================] - 99s 63ms/step - loss: 0.1257 - accuracy: 0.9560 - precision: 0.9564 - recall: 0.9556 - val_loss: 0.1722 - val_accuracy: 0.9418 - val_precision: 0.9683 - val_recall: 0.9135
# Epoch 20/100
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.1336 - accuracy: 0.9555 - precision: 0.9543 - recall: 0.9569 - val_loss: 0.1704 - val_accuracy: 0.9450 - val_precision: 0.9270 - val_recall: 0.9661
# Epoch 21/100
# 1563/1563 [==============================] - 89s 57ms/step - loss: 0.1232 - accuracy: 0.9580 - precision: 0.9591 - recall: 0.9569 - val_loss: 0.1519 - val_accuracy: 0.9486 - val_precision: 0.9595 - val_recall: 0.9367
# Epoch 22/100
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.1228 - accuracy: 0.9584 - precision: 0.9601 - recall: 0.9566 - val_loss: 0.1529 - val_accuracy: 0.9464 - val_precision: 0.9413 - val_recall: 0.9522
# Epoch 23/100
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.1164 - accuracy: 0.9602 - precision: 0.9606 - recall: 0.9598 - val_loss: 0.1649 - val_accuracy: 0.9440 - val_precision: 0.9701 - val_recall: 0.9162
# Epoch 24/100
# 1563/1563 [==============================] - 64s 41ms/step - loss: 0.1144 - accuracy: 0.9614 - precision: 0.9621 - recall: 0.9606 - val_loss: 0.1587 - val_accuracy: 0.9430 - val_precision: 0.9621 - val_recall: 0.9222
# Epoch 25/100
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.1121 - accuracy: 0.9625 - precision: 0.9640 - recall: 0.9608 - val_loss: 0.1696 - val_accuracy: 0.9466 - val_precision: 0.9371 - val_recall: 0.9574
# Epoch 26/100
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.1090 - accuracy: 0.9633 - precision: 0.9662 - recall: 0.9603 - val_loss: 0.1852 - val_accuracy: 0.9434 - val_precision: 0.9220 - val_recall: 0.9687
# Epoch 27/100
# 1563/1563 [==============================] - 59s 37ms/step - loss: 0.1090 - accuracy: 0.9637 - precision: 0.9672 - recall: 0.9600 - val_loss: 0.1579 - val_accuracy: 0.9501 - val_precision: 0.9506 - val_recall: 0.9496
# Epoch 28/100
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.1039 - accuracy: 0.9649 - precision: 0.9680 - recall: 0.9615 - val_loss: 0.1669 - val_accuracy: 0.9470 - val_precision: 0.9316 - val_recall: 0.9648
# Epoch 29/100
# 1563/1563 [==============================] - 59s 38ms/step - loss: 0.1048 - accuracy: 0.9650 - precision: 0.9672 - recall: 0.9627 - val_loss: 0.1578 - val_accuracy: 0.9512 - val_precision: 0.9473 - val_recall: 0.9554
# Epoch 30/100
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.1004 - accuracy: 0.9661 - precision: 0.9686 - recall: 0.9635 - val_loss: 0.1576 - val_accuracy: 0.9502 - val_precision: 0.9445 - val_recall: 0.9565
# Epoch 31/100
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.0984 - accuracy: 0.9675 - precision: 0.9693 - recall: 0.9656 - val_loss: 0.1597 - val_accuracy: 0.9508 - val_precision: 0.9482 - val_recall: 0.9537
# Transfer Learning training finished.

# %%
# Evaluate the model on the test dataset
val_loss, val_accuracy, val_precision, val_recall = MobileNet_model.evaluate(val_ds)

# Print the metrics
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
# Out:
# 313/313 [==============================] - 8s 24ms/step - loss: 0.1519 - accuracy: 0.9486 - precision: 0.9595 - recall: 0.9367
# Val Loss: 0.1519
# Val Accuracy: 0.9486
# Val Precision: 0.9595
# Val Recall: 0.9367

# %%
# Plot error rates and metric rates
plot_metrics(MobileNet_model_history, 'loss', "Training vs Validation Loss")
plot_metrics(MobileNet_model_history, 'accuracy', "Training vs Validation Accuracy")
plot_metrics(MobileNet_model_history, 'precision', "Training vs Validation Precision")
plot_metrics(MobileNet_model_history, 'recall', "Training vs Validation Recall")

# %%
# Get model predictions on validation/test dataset
val_pred_probs = MobileNet_model.predict(val_ds)

# Convert probabilities to class labels (sigmoid → binary)
val_pred_classes = (val_pred_probs > 0.5).astype(int).ravel()

# Confusion Matrix
cm = confusion_matrix(val_true_classes, val_pred_classes)

plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix – MobileNetV3Small")
plt.show()

f1 = f1_score(val_true_classes, val_pred_classes)
print(f"F1 Score: {f1:.4f}")

print(classification_report(
    val_true_classes,
    val_pred_classes,
    target_names=class_names
))
# Out:
# 313/313 [==============================] - 8s 23ms/step
# F1 Score: 0.9480
#               precision    recall  f1-score   support
#
#         FAKE       0.94      0.96      0.95     10000
#         REAL       0.96      0.94      0.95     10000
#
#     accuracy                           0.95     20000
#    macro avg       0.95      0.95      0.95     20000
# weighted avg       0.95      0.95      0.95     20000

# %% [markdown]
# The model with EfficientNet as the base is the clear winner with an accuracy of 97.29%; however, MobileNet is also a great option since its model size is significantly lower than EfficientNet's, with a minor decrease in performance.
