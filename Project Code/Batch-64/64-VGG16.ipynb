# %% [markdown]
# ## Fine-tuning CNN for AI-generated Image Detection
# In this notebook, we will explore the task of classifying images as real or AI-generated using fine-tuning techniques with several well-known CNN architectures. For this classification task, we will use the CIFAKE dataset, which includes both real and AI-generated images.
#
# Link for the dataset: [CIFAKE: Real and AI-Generated Synthetic Images](https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from IPython.display import Image
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
# Out:
# 2026-01-11 14:36:29.593994: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-11 14:36:29.594124: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-11 14:36:29.897886: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_dir = "/kaggle/input/cifake-real-and-ai-generated-synthetic-images/" # For Kaggle notebooks. If you run locally, point this line to the CIFAKE directory
print("Loading dataset from: " + dataset_dir)
# Out:
# Loading dataset from: /kaggle/input/cifake-real-and-ai-generated-synthetic-images/

# %%
# Check if GPUs are available for training 
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  2

# %%
img_height = 32
img_width = 32
batch_size = 64

# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/train",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

# Load the validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/test",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size,
  shuffle=False)

print("Training Classes:")
class_names = train_ds.class_names
print(class_names)

print("Testing Classes:")
class_names = val_ds.class_names
print(class_names)
# Out:
# Found 100000 files belonging to 2 classes.
# Found 20000 files belonging to 2 classes.
# Training Classes:
# ['FAKE', 'REAL']
# Testing Classes:
# ['FAKE', 'REAL']

# %% [markdown]
# Larger batch sizes are expected to result in significantly longer training times, especially with a substantial training set of 100,000 images. However, the compact size of the images effectively reduces the impact on training duration.

# %%
def plot_metrics(history, metric, title):
    # Train metric
    plt.plot(history.history[metric], label=f"Training {metric.capitalize()}")
    # Validation metric
    plt.plot(history.history['val_' + metric], label=f"Validation {metric.capitalize()}")
    plt.xlabel("Epochs")
    plt.ylabel(metric.capitalize())
    plt.title(title)
    plt.legend()
    plt.show()
    
# Constant values that will be shared by all the models
val_true_classes = np.concatenate([y for x, y in val_ds], axis = 0)  # Get true labels
class_names = ['FAKE', 'REAL']
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %% [markdown]
# ### Model Building
#
# All the models share the same architecture for a fair comparison: the input layer, followed by the base model with pre-trained weights from the imagenet, then a few dense layers, and then a unit output with a sigmoid activation function.
#
# Training is conducted with early stopping criteria monitoring the validation loss, and the best weights will be restored once the training is completed.

# %%
# Building the Transfer Learning model using VGG16
VGG_base_model = tf.keras.applications.VGG16(
    include_top = False, 
    weights = 'imagenet', 
    input_shape = (img_height, img_width, 3),
    pooling = 'max'
)
VGG_base_model.trainable = True

# Create a new model on top of the VGG16 base
inputs = tf.keras.Input(shape = (img_height, img_width, 3))
x = VGG_base_model(inputs, training = False)
x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001)(x)
x = Dense(256, 
          kernel_regularizer = regularizers.l2(0.01), 
          activity_regularizer = regularizers.l1(0.01), 
          bias_regularizer = regularizers.l1(0.01),
          activation = 'relu')(x)
x = Dropout(rate = .4, seed = 512)(x)       
x = Dense(64, activation = 'relu')(x)
outputs = Dense(1, activation = 'sigmoid')(x)
VGG_model = tf.keras.Model(inputs, outputs)

# Compile the Transfer Learning model
VGG_model.compile(
    optimizer = tf.keras.optimizers.Adamax(learning_rate = .001),
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# Build the Transfer Learning model so we can see a summary
VGG_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  vgg16 (Functional)          (None, 512)               14714688
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 14864577 (56.70 MB)
# Trainable params: 14863553 (56.70 MB)
# Non-trainable params: 1024 (4.00 KB)
# _________________________________________________________________

# %%
# Visualize the VGG model architecture
tf.keras.utils.plot_model(VGG_model, show_shapes = True, to_file = 'VGG_model.png')
Image('VGG_model.png')

# %%
print("Starting training with Transfer Learning using VGG16...")
VGG_model_history = VGG_model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 100,
    verbose = 1,
    callbacks = [early_stopping]
)
print("Transfer Learning training finished.")
# Out:
# Starting training with Transfer Learning using VGG16...
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768142480.138280     111 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1563/1563 [==============================] - 203s 121ms/step - loss: 0.6133 - accuracy: 0.8719 - precision: 0.8651 - recall: 0.8811 - val_loss: 0.4378 - val_accuracy: 0.8219 - val_precision: 0.9880 - val_recall: 0.6516
# Epoch 2/100
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.2109 - accuracy: 0.9346 - precision: 0.9391 - recall: 0.9296 - val_loss: 0.1773 - val_accuracy: 0.9470 - val_precision: 0.9266 - val_recall: 0.9710
# Epoch 3/100
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.1591 - accuracy: 0.9518 - precision: 0.9542 - recall: 0.9492 - val_loss: 0.1828 - val_accuracy: 0.9481 - val_precision: 0.9229 - val_recall: 0.9778
# Epoch 4/100
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.1400 - accuracy: 0.9570 - precision: 0.9599 - recall: 0.9538 - val_loss: 0.1539 - val_accuracy: 0.9478 - val_precision: 0.9689 - val_recall: 0.9253
# Epoch 5/100
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.1173 - accuracy: 0.9648 - precision: 0.9667 - recall: 0.9628 - val_loss: 0.1402 - val_accuracy: 0.9585 - val_precision: 0.9370 - val_recall: 0.9830
# Epoch 6/100
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.0970 - accuracy: 0.9717 - precision: 0.9739 - recall: 0.9693 - val_loss: 0.1279 - val_accuracy: 0.9564 - val_precision: 0.9315 - val_recall: 0.9853
# Epoch 7/100
# 1563/1563 [==============================] - 67s 42ms/step - loss: 0.0810 - accuracy: 0.9775 - precision: 0.9776 - recall: 0.9775 - val_loss: 0.1350 - val_accuracy: 0.9620 - val_precision: 0.9741 - val_recall: 0.9491
# Epoch 8/100
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.0647 - accuracy: 0.9833 - precision: 0.9831 - recall: 0.9836 - val_loss: 0.1254 - val_accuracy: 0.9639 - val_precision: 0.9792 - val_recall: 0.9479
# Epoch 9/100
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.0530 - accuracy: 0.9871 - precision: 0.9864 - recall: 0.9878 - val_loss: 0.1687 - val_accuracy: 0.9552 - val_precision: 0.9313 - val_recall: 0.9829
# Epoch 10/100
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.0464 - accuracy: 0.9889 - precision: 0.9878 - recall: 0.9899 - val_loss: 0.1268 - val_accuracy: 0.9649 - val_precision: 0.9680 - val_recall: 0.9616
# Epoch 11/100
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.0407 - accuracy: 0.9909 - precision: 0.9901 - recall: 0.9918 - val_loss: 0.2012 - val_accuracy: 0.9585 - val_precision: 0.9847 - val_recall: 0.9316
# Epoch 12/100
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.0348 - accuracy: 0.9926 - precision: 0.9922 - recall: 0.9931 - val_loss: 0.2013 - val_accuracy: 0.9563 - val_precision: 0.9823 - val_recall: 0.9293
# Epoch 13/100
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.0318 - accuracy: 0.9935 - precision: 0.9930 - recall: 0.9940 - val_loss: 0.1399 - val_accuracy: 0.9686 - val_precision: 0.9702 - val_recall: 0.9668
# Epoch 14/100
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.0273 - accuracy: 0.9945 - precision: 0.9940 - recall: 0.9951 - val_loss: 0.1737 - val_accuracy: 0.9616 - val_precision: 0.9413 - val_recall: 0.9846
# Epoch 15/100
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.0258 - accuracy: 0.9952 - precision: 0.9948 - recall: 0.9957 - val_loss: 0.1892 - val_accuracy: 0.9626 - val_precision: 0.9852 - val_recall: 0.9393
# Epoch 16/100
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.0232 - accuracy: 0.9956 - precision: 0.9951 - recall: 0.9962 - val_loss: 0.2035 - val_accuracy: 0.9645 - val_precision: 0.9814 - val_recall: 0.9468
# Epoch 17/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.0220 - accuracy: 0.9959 - precision: 0.9955 - recall: 0.9962 - val_loss: 0.1554 - val_accuracy: 0.9683 - val_precision: 0.9805 - val_recall: 0.9556
# Epoch 18/100
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.0214 - accuracy: 0.9959 - precision: 0.9956 - recall: 0.9962 - val_loss: 0.1600 - val_accuracy: 0.9682 - val_precision: 0.9603 - val_recall: 0.9768
# Transfer Learning training finished.

# %%
# Evaluate the model on the test dataset
val_loss, val_accuracy, val_precision, val_recall = VGG_model.evaluate(val_ds)

# Print the metrics
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
# Out:
# 313/313 [==============================] - 8s 27ms/step - loss: 0.1254 - accuracy: 0.9639 - precision: 0.9792 - recall: 0.9479
# Val Loss: 0.1254
# Val Accuracy: 0.9639
# Val Precision: 0.9792
# Val Recall: 0.9479

# %%
# Plot error rates and metric rates
plot_metrics(VGG_model_history, 'loss', "Training vs Validation Loss")
plot_metrics(VGG_model_history, 'accuracy', "Training vs Validation Accuracy")
plot_metrics(VGG_model_history, 'precision', "Training vs Validation Precision")
plot_metrics(VGG_model_history, 'recall', "Training vs Validation Recall")

# %%
# Get model predictions on validation/test dataset
val_pred_probs = VGG_model.predict(val_ds)

# Convert probabilities to class labels (sigmoid → binary)
val_pred_classes = (val_pred_probs > 0.5).astype(int).ravel()

# Confusion Matrix
cm = confusion_matrix(val_true_classes, val_pred_classes)

plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix – VGG16")
plt.show()

f1 = f1_score(val_true_classes, val_pred_classes)
print(f"F1 Score: {f1:.4f}")

print(classification_report(
    val_true_classes,
    val_pred_classes,
    target_names=class_names
))
# Out:
# 313/313 [==============================] - 8s 24ms/step
# F1 Score: 0.9633
#               precision    recall  f1-score   support
#
#         FAKE       0.95      0.98      0.96     10000
#         REAL       0.98      0.95      0.96     10000
#
#     accuracy                           0.96     20000
#    macro avg       0.96      0.96      0.96     20000
# weighted avg       0.96      0.96      0.96     20000

# %% [markdown]
# The model with EfficientNet as the base is the clear winner with an accuracy of 97.29%; however, MobileNet is also a great option since its model size is significantly lower than EfficientNet's, with a minor decrease in performance.
